# %%
pip install igraph
# Out:
# ...
#
# ...
#      ---------------------------------------- 2.8/2.8 MB 11.9 MB/s eta 0:00:00
# ...
#   Using cached texttable-1.6.4-py2.py3-none-any.whl (10 kB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\KKo1\Anaconda3\envs\py38\python.exe -m pip install --upgrade pip' command.

# %%
pip install louvain
# Out:
# ...
#
#   Using cached louvain-0.7.1-cp39-cp39-win_amd64.whl (94 kB)
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\KKo1\Anaconda3\envs\py38\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import scanpy as sc
import numpy as np
from numpy import linalg as la
from scipy.sparse import issparse
import loompy
import anndata
import scvelo as scv
scv.logging.print_version()
# Out:
# Running scvelo 0.2.5 (python 3.8.16) on 2023-06-06 02:44.

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.9.3 anndata==0.9.1 umap==0.5.3 numpy==1.23.5 scipy==1.10.1 pandas==1.3.5 scikit-learn==1.0.2 statsmodels==0.13.5 python-igraph==0.10.4 louvain==0.8.0 pynndescent==0.5.5

# %%
import os
os.chdir('F:/Ko/67ESCC_PCN_integration_07-19-22/immune_cell_T4_M4')

# %%
import scanpy.external as sce

# %%
adata_1 = sc.read('P009A_for_cellchat.h5ad')
adata_2 = sc.read('P036_for_cellchat.h5ad')
adata_3 = sc.read('P126_for_cellchat.h5ad')
adata_4 = sc.read('P038_for_cellchat.h5ad')
adata_5 = sc.read('P104_for_cellchat.h5ad')
adata_6 = sc.read('P082_for_cellchat.h5ad')
adata_7 = sc.read('P063_for_cellchat.h5ad')
adata_8 = sc.read('P056_for_cellchat.h5ad')
adata_9 = sc.read('P866_for_cellchat.h5ad')
adata_10 = sc.read('P686_for_cellchat.h5ad')
adata_11 = sc.read('P658_for_cellchat.h5ad')
adata_12 = sc.read('P787_for_cellchat.h5ad')
adata_13 = sc.read('P986_for_cellchat.h5ad')
adata_14 = sc.read('P585_for_cellchat.h5ad')
adata_15 = sc.read('P944_for_cellchat.h5ad')
adata_16 = sc.read('P865_for_cellchat.h5ad')
adata_17 = sc.read('P087_for_cellchat.h5ad')
adata_18 = sc.read('P047_for_cellchat.h5ad')
adata_19 = sc.read('P040_for_cellchat.h5ad')
adata_20 = sc.read('P044_for_cellchat.h5ad')
adata_21 = sc.read('P022_for_cellchat.h5ad')

# %%
adata_1.obs['celltype_detail']
# Out:
# AAACCTGAGATCCTGT-1-12-0-0-0-0     Tumor
# AAACCTGAGCGTGTCC-1-12-0-0-0-0     Tumor
# AAACCTGAGGTGCTTT-1-12-0-0-0-0     Tumor
# AAACCTGAGTCCGGTC-1-12-0-0-0-0     Tumor
# AAACCTGAGTTAGCGG-1-12-0-0-0-0     Tumor
#                                   ...
# TTTGGTTGTTTGACAC-1-9-0-1-0       T cell
# TTTGGTTGTTTGCATG-1-9-0-1-0       T cell
# TTTGTCAAGCCAGTAG-1-9-0-1-0       T cell
# TTTGTCAGTCTAAACC-1-9-0-1-0       T cell
# TTTGTCATCAGGTTCA-1-9-0-1-0       T cell
# Name: celltype_detail, Length: 16391, dtype: category
# Categories (4, object): ['Fibroblast', 'T cell', 'Tumor', 'effector T cell']

# %%
#009A
adata_009 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796890',
                            var_names='gene_symbols', cache=True)
#686
adata_686 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796861/filtered_feature_bc_matrix',
                            var_names='gene_symbols', cache=True)
#658
adata_658_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796863/filtered_feature_bc_matrix',
                            var_names='gene_symbols', cache=True)
adata_658_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796864/filtered_feature_bc_matrix',
                            var_names='gene_symbols', cache=True)
                           
#865
#051 has been relaced with 865
adata_865 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796882',
                            var_names='gene_symbols', cache=True)

#986
adata_986 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796874',
                            var_names='gene_symbols', cache=True)
#944
adata_944 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796876',
                            var_names='gene_symbols', cache=True)
#866
adata_866 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796880',
                            var_names='gene_symbols', cache=True)
#787
adata_787 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796887',
                            var_names='gene_symbols', cache=True)
#585
adata_585 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796868',
                            var_names='gene_symbols', cache=True)
# Out:
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796890-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796861-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796863-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796864-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796882-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796874-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796876-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796880-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796887-matrix.h5ad
# ...

# %%
#126
adata_126_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3593/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_126_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3538/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#104
adata_104_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3595/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_104_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3540/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#087
adata_087_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3600/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_087_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3545/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#082
adata_082_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3603/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_082_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3548/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#063
adata_063_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3488/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_063_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3555/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#056
adata_056_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3491/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_056_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3558/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#044
adata_044_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3498/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_044_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3565/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#040
adata_040_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3501/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_040_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3567/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#047
adata_047_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3500/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_047_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3568/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#038
adata_038_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3503/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_038_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3570/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#036
adata_036_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3505/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_036_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3572/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#022
adata_022_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3515/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_022_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3582/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
# Out:
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3593-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3538-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3595-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3540-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3600-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3545-filtered_feature_bc_matrix-matrix.h5ad
# ...

# %%
adata_658 = adata_658_1.concatenate(adata_658_2)
adata_126 = adata_126_1.concatenate(adata_126_2)
adata_104 = adata_104_1.concatenate(adata_104_2)
adata_087 = adata_087_1.concatenate(adata_087_2)
adata_082 = adata_082_1.concatenate(adata_082_2)
adata_063 = adata_063_1.concatenate(adata_063_2)
adata_056 = adata_056_1.concatenate(adata_056_2)
adata_044 = adata_044_1.concatenate(adata_044_2)
adata_040 = adata_040_1.concatenate(adata_040_2)
adata_047 = adata_047_1.concatenate(adata_047_2)
adata_038 = adata_038_1.concatenate(adata_038_2)
adata_036 = adata_036_1.concatenate(adata_036_2)
adata_022 = adata_022_1.concatenate(adata_022_2)

# %%
adata_1.obs
# Out:
#                                n_genes  n_genes_by_counts  total_counts  \
# AAACCTGAGATCCTGT-1-12-0-0-0-0   1004.0                979    523.773376
# AAACCTGAGCGTGTCC-1-12-0-0-0-0    439.0                432    432.101624
# AAACCTGAGGTGCTTT-1-12-0-0-0-0    609.0                594    469.512177
# AAACCTGAGTCCGGTC-1-12-0-0-0-0    671.0                658    486.834625
# AAACCTGAGTTAGCGG-1-12-0-0-0-0    672.0                653    502.997253
# ...                                ...                ...           ...
# TTTGGTTGTTTGACAC-1-9-0-1-0       653.0                622    456.865601
# TTTGGTTGTTTGCATG-1-9-0-1-0       732.0                717    455.828156
# TTTGTCAAGCCAGTAG-1-9-0-1-0      1071.0               1060    468.670959
# TTTGTCAGTCTAAACC-1-9-0-1-0      1339.0               1325    525.458313
# TTTGTCATCAGGTTCA-1-9-0-1-0       738.0                706    445.791748
#
#                                total_counts_mt  pct_counts_mt tissue patient  \
# ...

# %%
adata_009.obs
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
scv.utils.clean_obs_names(adata_1)
scv.utils.clean_obs_names(adata_2)
scv.utils.clean_obs_names(adata_3)
scv.utils.clean_obs_names(adata_4)
scv.utils.clean_obs_names(adata_5)
scv.utils.clean_obs_names(adata_6)
scv.utils.clean_obs_names(adata_7)
scv.utils.clean_obs_names(adata_8)
scv.utils.clean_obs_names(adata_9)
scv.utils.clean_obs_names(adata_10)
scv.utils.clean_obs_names(adata_11)
scv.utils.clean_obs_names(adata_12)
scv.utils.clean_obs_names(adata_13)
scv.utils.clean_obs_names(adata_14)
scv.utils.clean_obs_names(adata_15)
scv.utils.clean_obs_names(adata_16)
scv.utils.clean_obs_names(adata_17)
scv.utils.clean_obs_names(adata_18)
scv.utils.clean_obs_names(adata_19)
scv.utils.clean_obs_names(adata_20)
scv.utils.clean_obs_names(adata_21)

scv.utils.clean_obs_names(adata_009)
scv.utils.clean_obs_names(adata_036)
scv.utils.clean_obs_names(adata_126)
scv.utils.clean_obs_names(adata_038)
scv.utils.clean_obs_names(adata_104)
scv.utils.clean_obs_names(adata_082)
scv.utils.clean_obs_names(adata_063)
scv.utils.clean_obs_names(adata_056)
scv.utils.clean_obs_names(adata_866)
scv.utils.clean_obs_names(adata_686)
scv.utils.clean_obs_names(adata_658)
scv.utils.clean_obs_names(adata_787)
scv.utils.clean_obs_names(adata_866)
scv.utils.clean_obs_names(adata_986)
scv.utils.clean_obs_names(adata_787)
scv.utils.clean_obs_names(adata_986)
scv.utils.clean_obs_names(adata_585)
scv.utils.clean_obs_names(adata_944)
scv.utils.clean_obs_names(adata_865)
scv.utils.clean_obs_names(adata_087)
scv.utils.clean_obs_names(adata_047)
scv.utils.clean_obs_names(adata_040)
scv.utils.clean_obs_names(adata_044)
scv.utils.clean_obs_names(adata_022)

# %%
adata_1_3= scv.utils.merge(adata_1, adata_009)
adata_2_3= scv.utils.merge(adata_2, adata_036)
adata_3_3= scv.utils.merge(adata_3, adata_126)
adata_4_3= scv.utils.merge(adata_4, adata_038)
adata_5_3= scv.utils.merge(adata_5, adata_104)
adata_6_3= scv.utils.merge(adata_6, adata_082)
adata_7_3= scv.utils.merge(adata_7, adata_063)
adata_8_3= scv.utils.merge(adata_8, adata_056)
adata_9_3= scv.utils.merge(adata_9, adata_866)
adata_10_3= scv.utils.merge(adata_10, adata_686)
adata_11_3= scv.utils.merge(adata_11, adata_658)
adata_12_3= scv.utils.merge(adata_12, adata_787)
adata_13_3= scv.utils.merge(adata_13, adata_986)
adata_14_3= scv.utils.merge(adata_14, adata_585)
adata_15_3= scv.utils.merge(adata_15, adata_944)
adata_16_3= scv.utils.merge(adata_16, adata_865)
adata_17_3= scv.utils.merge(adata_17, adata_087)
adata_18_3= scv.utils.merge(adata_18, adata_047)
adata_19_3= scv.utils.merge(adata_19, adata_040)
adata_20_3= scv.utils.merge(adata_20, adata_044)
adata_21_3= scv.utils.merge(adata_21, adata_022)

# %%
adata_1_3.obs
# Out:
#                 n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCTGAGATC     1004.0                979    523.773376        14.157605
# AAACCTGAGCGT      439.0                432    432.101624        19.211973
# AAACCTGAGGTG      609.0                594    469.512177        12.005977
# AAACCTGAGTCC      671.0                658    486.834625        16.676079
# AAACCTGAGTTA      672.0                653    502.997253        16.186182
# ...                 ...                ...           ...              ...
# TTTGGTTGTTTG-1    653.0                622    456.865601         7.904017
# TTTGGTTGTTTG-2    732.0                717    455.828156        15.252275
# TTTGTCAAGCCA     1071.0               1060    468.670959        12.711347
# TTTGTCAGTCTA     1339.0               1325    525.458313        13.334949
# TTTGTCATCAGG      738.0                706    445.791748         5.621206
#
#                 pct_counts_mt tissue patient leiden batch  total_counts_ribo  \
# ...

# %%
adata_009.obs['celltype_detail'] = adata_1_3.obs['celltype_detail']
adata_009.obs['celltype'] = adata_1_3.obs['celltype']
adata_009.obs['crude'] = adata_1_3.obs['crude']
adata_009.obs['patient'] = adata_1_3.obs['patient']

adata_009_3 = adata_009[adata_009.obs['patient'].isin(['P009A'])]

# %%
adata_009.obs
# Out:
#              sample_batch celltype_detail celltype   crude patient
# AAACCTGAGAGC       TTCT-1          T cell       19  T cell   P009A
# AAACCTGAGATC       CTGT-1           Tumor    Tumor   Tumor   P009A
# AAACCTGAGCGT       GTCC-1           Tumor    Tumor   Tumor   P009A
# AAACCTGAGGTG       CTTT-1           Tumor    Tumor   Tumor   P009A
# AAACCTGAGTCC       GGTC-1           Tumor    Tumor   Tumor   P009A
# ...                   ...             ...      ...     ...     ...
# TTTGTCATCGGC       GCTA-1           Tumor    Tumor   Tumor   P009A
# TTTGTCATCTCG       ATGA-1           Tumor    Tumor   Tumor   P009A
# TTTGTCATCTGT       CAAG-1           Tumor    Tumor   Tumor   P009A
# TTTGTCATCTTC       GAGA-1           Tumor    Tumor   Tumor   P009A
# TTTGTCATCTTT       AGGG-1           Tumor    Tumor   Tumor   P009A
#
# [16579 rows x 5 columns]

# %%
adata_009_3.obs
# Out:
#              sample_batch celltype_detail celltype   crude patient
# AAACCTGAGAGC       TTCT-1          T cell       19  T cell   P009A
# AAACCTGAGATC       CTGT-1           Tumor    Tumor   Tumor   P009A
# AAACCTGAGCGT       GTCC-1           Tumor    Tumor   Tumor   P009A
# AAACCTGAGGTG       CTTT-1           Tumor    Tumor   Tumor   P009A
# AAACCTGAGTCC       GGTC-1           Tumor    Tumor   Tumor   P009A
# ...                   ...             ...      ...     ...     ...
# TTTGTCATCGGC       GCTA-1           Tumor    Tumor   Tumor   P009A
# TTTGTCATCTCG       ATGA-1           Tumor    Tumor   Tumor   P009A
# TTTGTCATCTGT       CAAG-1           Tumor    Tumor   Tumor   P009A
# TTTGTCATCTTC       GAGA-1           Tumor    Tumor   Tumor   P009A
# TTTGTCATCTTT       AGGG-1           Tumor    Tumor   Tumor   P009A
#
# [16391 rows x 5 columns]

# %%
adata_009_3.obs['celltype_detail']
# Out:
# AAACCTGAGAGC    T cell
# AAACCTGAGATC     Tumor
# AAACCTGAGCGT     Tumor
# AAACCTGAGGTG     Tumor
# AAACCTGAGTCC     Tumor
#                  ...
# TTTGTCATCGGC     Tumor
# TTTGTCATCTCG     Tumor
# TTTGTCATCTGT     Tumor
# TTTGTCATCTTC     Tumor
# TTTGTCATCTTT     Tumor
# Name: celltype_detail, Length: 16391, dtype: category
# Categories (4, object): ['Fibroblast', 'T cell', 'Tumor', 'effector T cell']

# %%
adata_1_3.obs['celltype_detail']
# Out:
# AAACCTGAGATC       Tumor
# AAACCTGAGCGT       Tumor
# AAACCTGAGGTG       Tumor
# AAACCTGAGTCC       Tumor
# AAACCTGAGTTA       Tumor
#                    ...
# TTTGGTTGTTTG-1    T cell
# TTTGGTTGTTTG-2    T cell
# TTTGTCAAGCCA      T cell
# TTTGTCAGTCTA      T cell
# TTTGTCATCAGG      T cell
# Name: celltype_detail, Length: 16391, dtype: category
# Categories (4, object): ['Fibroblast', 'T cell', 'Tumor', 'effector T cell']

# %%
adata_009_3.X[1:10,1:10]
# Out:
# <9x9 sparse matrix of type '<class 'numpy.float32'>'
# 	with 0 stored elements in Compressed Sparse Row format>

# %%
adata_036.obs['celltype_detail'] = adata_2_3.obs['celltype_detail']
adata_036.obs['celltype'] = adata_2_3.obs['celltype']
adata_036.obs['crude'] = adata_2_3.obs['crude']
adata_036.obs['patient'] = adata_2_3.obs['patient']

adata_036_3 = adata_036[adata_036.obs['patient'].isin(['P036'])]

adata_126.obs['celltype_detail'] = adata_3_3.obs['celltype_detail']
adata_126.obs['celltype'] = adata_3_3.obs['celltype']
adata_126.obs['crude'] = adata_3_3.obs['crude']
adata_126.obs['patient'] = adata_3_3.obs['patient']

adata_126_3 = adata_126[adata_126.obs['patient'].isin(['P126'])]

adata_038.obs['celltype_detail'] = adata_4_3.obs['celltype_detail']
adata_038.obs['celltype'] = adata_4_3.obs['celltype']
adata_038.obs['crude'] = adata_4_3.obs['crude']
adata_038.obs['patient'] = adata_4_3.obs['patient']

adata_038_3 = adata_038[adata_038.obs['patient'].isin(['P038'])]

adata_104.obs['celltype_detail'] = adata_5_3.obs['celltype_detail']
adata_104.obs['celltype'] = adata_5_3.obs['celltype']
adata_104.obs['crude'] = adata_5_3.obs['crude']
adata_104.obs['patient'] = adata_5_3.obs['patient']


adata_104_3 = adata_104[adata_104.obs['patient'].isin(['P104'])]

adata_082.obs['celltype_detail'] = adata_6_3.obs['celltype_detail']
adata_082.obs['celltype'] = adata_6_3.obs['celltype']
adata_082.obs['crude'] = adata_6_3.obs['crude']
adata_082.obs['patient'] = adata_6_3.obs['patient']


adata_082_3 = adata_082[adata_082.obs['patient'].isin(['P082'])]

adata_063.obs['celltype_detail'] = adata_7_3.obs['celltype_detail']
adata_063.obs['celltype'] = adata_7_3.obs['celltype']
adata_063.obs['crude'] = adata_7_3.obs['crude']
adata_063.obs['patient'] = adata_7_3.obs['patient']


adata_063_3 = adata_063[adata_063.obs['patient'].isin(['P063'])]

adata_056.obs['celltype_detail'] = adata_8_3.obs['celltype_detail']
adata_056.obs['celltype'] = adata_8_3.obs['celltype']
adata_056.obs['crude'] = adata_8_3.obs['crude']
adata_056.obs['patient'] = adata_8_3.obs['patient']


adata_056_3 = adata_056[adata_056.obs['patient'].isin(['P056'])]

adata_866.obs['celltype_detail'] = adata_9_3.obs['celltype_detail']
adata_866.obs['celltype'] = adata_9_3.obs['celltype']
adata_866.obs['crude'] = adata_9_3.obs['crude']
adata_866.obs['patient'] = adata_9_3.obs['patient']


adata_866_3 = adata_866[adata_866.obs['patient'].isin(['P866'])]

adata_686.obs['celltype_detail'] = adata_10_3.obs['celltype_detail']
adata_686.obs['celltype'] = adata_10_3.obs['celltype']
adata_686.obs['crude'] = adata_10_3.obs['crude']
adata_686.obs['patient'] = adata_10_3.obs['patient']

adata_686_3 = adata_686[adata_686.obs['patient'].isin(['P686'])]

adata_658.obs['celltype_detail'] = adata_11_3.obs['celltype_detail']
adata_658.obs['celltype'] = adata_11_3.obs['celltype']
adata_658.obs['crude'] = adata_11_3.obs['crude']
adata_658.obs['patient'] = adata_11_3.obs['patient']

adata_658_3 = adata_658[adata_658.obs['patient'].isin(['P658'])]

adata_787.obs['celltype_detail'] = adata_12_3.obs['celltype_detail']
adata_787.obs['celltype'] = adata_12_3.obs['celltype']
adata_787.obs['crude'] = adata_12_3.obs['crude']
adata_787.obs['patient'] = adata_12_3.obs['patient']


adata_787_3 = adata_787[adata_787.obs['patient'].isin(['P787'])]

adata_986.obs['celltype_detail'] = adata_13_3.obs['celltype_detail']
adata_986.obs['celltype'] = adata_13_3.obs['celltype']
adata_986.obs['crude'] = adata_13_3.obs['crude']
adata_986.obs['patient'] = adata_13_3.obs['patient']


adata_986_3 = adata_986[adata_986.obs['patient'].isin(['P986'])]

adata_585.obs['celltype_detail'] = adata_14_3.obs['celltype_detail']
adata_585.obs['celltype'] = adata_14_3.obs['celltype']
adata_585.obs['crude'] = adata_14_3.obs['crude']
adata_585.obs['patient'] = adata_14_3.obs['patient']


adata_585_3 = adata_585[adata_585.obs['patient'].isin(['P585'])]

adata_944.obs['celltype_detail'] = adata_15_3.obs['celltype_detail']
adata_944.obs['celltype'] = adata_15_3.obs['celltype']
adata_944.obs['crude'] = adata_15_3.obs['crude']
adata_944.obs['patient'] = adata_15_3.obs['patient']


adata_944_3 = adata_944[adata_944.obs['patient'].isin(['P944'])]

adata_865.obs['celltype_detail'] = adata_16_3.obs['celltype_detail']
adata_865.obs['celltype'] = adata_16_3.obs['celltype']
adata_865.obs['crude'] = adata_16_3.obs['crude']
adata_865.obs['patient'] = adata_16_3.obs['patient']


adata_865_3 = adata_865[adata_865.obs['patient'].isin(['P865'])]

adata_087.obs['celltype_detail'] = adata_17_3.obs['celltype_detail']
adata_087.obs['celltype'] = adata_17_3.obs['celltype']
adata_087.obs['crude'] = adata_17_3.obs['crude']
adata_087.obs['patient'] = adata_17_3.obs['patient']


adata_087_3 = adata_087[adata_087.obs['patient'].isin(['P087'])]

adata_047.obs['celltype_detail'] = adata_18_3.obs['celltype_detail']
adata_047.obs['celltype'] = adata_18_3.obs['celltype']
adata_047.obs['crude'] = adata_18_3.obs['crude']
adata_047.obs['patient'] = adata_18_3.obs['patient']


adata_047_3 = adata_047[adata_047.obs['patient'].isin(['P047'])]

adata_040.obs['celltype_detail'] = adata_19_3.obs['celltype_detail']
adata_040.obs['celltype'] = adata_19_3.obs['celltype']
adata_040.obs['crude'] = adata_19_3.obs['crude']
adata_040.obs['patient'] = adata_19_3.obs['patient']


adata_040_3 = adata_040[adata_040.obs['patient'].isin(['P040'])]

adata_044.obs['celltype_detail'] = adata_20_3.obs['celltype_detail']
adata_044.obs['celltype'] = adata_20_3.obs['celltype']
adata_044.obs['crude'] = adata_20_3.obs['crude']
adata_044.obs['patient'] = adata_20_3.obs['patient']


adata_044_3 = adata_044[adata_044.obs['patient'].isin(['P044'])]

adata_022.obs['celltype_detail'] = adata_21_3.obs['celltype_detail']
adata_022.obs['celltype'] = adata_21_3.obs['celltype']
adata_022.obs['crude'] = adata_21_3.obs['crude']
adata_022.obs['patient'] = adata_21_3.obs['patient']


adata_022_3 = adata_022[adata_022.obs['patient'].isin(['P022'])]

# %%
adata_044_3
# Out:
# View of AnnData object with n_obs × n_vars = 7002 × 36601
#     obs: 'batch', 'sample_batch', 'celltype_detail', 'celltype', 'crude', 'patient'
#     var: 'gene_ids', 'feature_types'

# %%
adata_009_3.write('P009A_overlaid_for_cellchat.h5ad', compression='gzip')

# %%
adata_036_3.write('P036_overlaid_for_cellchat.h5ad', compression='gzip')
adata_126_3.write('P126_overlaid_for_cellchat.h5ad', compression='gzip')
adata_038_3.write('P038_overlaid_for_cellchat.h5ad', compression='gzip')
adata_104_3.write('P104_overlaid_for_cellchat.h5ad', compression='gzip')
adata_082_3.write('P082_overlaid_for_cellchat.h5ad', compression='gzip')
adata_063_3.write('P063_overlaid_for_cellchat.h5ad', compression='gzip')
adata_056_3.write('P056_overlaid_for_cellchat.h5ad', compression='gzip')
adata_866_3.write('P866_overlaid_for_cellchat.h5ad', compression='gzip')
adata_686_3.write('P686_overlaid_for_cellchat.h5ad', compression='gzip')
adata_658_3.write('P658_overlaid_for_cellchat.h5ad', compression='gzip')
adata_787_3.write('P787_overlaid_for_cellchat.h5ad', compression='gzip')
adata_986_3.write('P986_overlaid_for_cellchat.h5ad', compression='gzip')
adata_585_3.write('P585_overlaid_for_cellchat.h5ad', compression='gzip')
adata_944_3.write('P944_overlaid_for_cellchat.h5ad', compression='gzip')
adata_865_3.write('P865_overlaid_for_cellchat.h5ad', compression='gzip')
adata_087_3.write('P087_overlaid_for_cellchat.h5ad', compression='gzip')
adata_047_3.write('P047_overlaid_for_cellchat.h5ad', compression='gzip')
adata_040_3.write('P040_overlaid_for_cellchat.h5ad', compression='gzip')
adata_044_3.write('P044_overlaid_for_cellchat.h5ad', compression='gzip')
adata_022_3.write('P022_overlaid_for_cellchat.h5ad', compression='gzip')

# %%
adata_866_3.obs
# Out:
#              sample_batch celltype_detail celltype         crude patient
# AAACCTGAGACA       CTAA-1          T cell       11        T cell    P866
# AAACCTGAGCAA       CGGT-1           Tumor    Tumor         Tumor    P866
# AAACCTGAGCGC       CTTG-1           Tumor    Tumor         Tumor    P866
# AAACCTGAGGGT       TCCC-1          B cell       15        B cell    P866
# AAACCTGAGTGA       CATA-1           Tumor    Tumor         Tumor    P866
# ...                   ...             ...      ...           ...     ...
# TTTGTCATCGCC       TGTT-1          T cell       11        T cell    P866
# TTTGTCATCGTC       TGCT-1          T cell       11        T cell    P866
# TTTGTCATCTAA       GCCA-1   M1 Macrophage       14  Myeloid cell    P866
# TTTGTCATCTAC       CTGC-1           Tumor    Tumor         Tumor    P866
# TTTGTCATCTGA       AAGA-1          T cell       11        T cell    P866
#
# [7039 rows x 5 columns]

# %%
# Group B
#'P048','039','P127','P054','P016','P002','P128','P031','P026','P012','P027','P079','P076','P052','P028',
#'P080','P062','P846','P181','P107','P089','P083','P074'
adata_31 = sc.read('P048_for_cellchat.h5ad')
adata_32 = sc.read('P039_for_cellchat.h5ad')
adata_33 = sc.read('P127_for_cellchat.h5ad')
adata_34 = sc.read('P054_for_cellchat.h5ad')
adata_35 = sc.read('P016_for_cellchat.h5ad')
adata_36 = sc.read('P002_for_cellchat.h5ad')
adata_37 = sc.read('P128_for_cellchat.h5ad')
adata_38 = sc.read('P031_for_cellchat.h5ad')
adata_39 = sc.read('P026_for_cellchat.h5ad')
adata_40 = sc.read('P012_for_cellchat.h5ad')
adata_41 = sc.read('P027_for_cellchat.h5ad')
adata_42 = sc.read('P079_for_cellchat.h5ad')
adata_43 = sc.read('P076_for_cellchat.h5ad')
adata_44 = sc.read('P052_for_cellchat.h5ad')
adata_45 = sc.read('P028_for_cellchat.h5ad')
adata_46 = sc.read('P080_for_cellchat.h5ad')
adata_47 = sc.read('P062_for_cellchat.h5ad')
adata_48 = sc.read('P846_for_cellchat.h5ad')
adata_49 = sc.read('P836_for_cellchat.h5ad')
adata_50 = sc.read('P107_for_cellchat.h5ad')
adata_51 = sc.read('P089_for_cellchat.h5ad')
adata_52 = sc.read('P083_for_cellchat.h5ad')
adata_53 = sc.read('P074_for_cellchat.h5ad')

# %%
# Group B
#'P048','039','P127','P054','P016','P002','P128','P031','P026','P012','P027','P079','P076','P052','P028',
#'P080','P062','P846','P181','P107','P089','P083','P074'


#836
#181 has been replaced with 836
adata_836 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796886',
                            var_names='gene_symbols', cache=True)
#846
adata_846_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796883',
                            var_names='gene_symbols', cache=True)
adata_846_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/11ESCC/16796884',
                            var_names='gene_symbols', cache=True)
# Out:
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796886-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796883-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-11ESCC-16796884-matrix.h5ad

# %%
# Group B
#'P048','P039','P127','P054','P016','P002','P128','P031','P026','P012','P027','P079','P076','P052','P028',
#'P080','P062','P846','P181','P107','P089','P083','P074'

#P048
adata_048_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3496/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_048_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3563/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P039
adata_039_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3502/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_039_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3569/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P127
adata_127_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3592/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_127_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3537/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P054
adata_054_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3493/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_054_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3559/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P016
adata_016_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3520/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_016_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3509/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P002
adata_002_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3527/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_002_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3610/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P128
adata_128_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3590/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_128_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3536/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P031
adata_031_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3507/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_031_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3574/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P026
adata_026_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3511/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_026_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3579/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P012
adata_012_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3523/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_012_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3531/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P027
adata_027_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3510/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_027_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3578/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P079
adata_079_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3604/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_079_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3549/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P076
adata_076_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3584/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_076_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3583/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P052
adata_052_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3494/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_052_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3561/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P028
adata_028_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3513/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_028_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3577/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P080
adata_080_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3607/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_080_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3552/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P062
adata_062_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3492/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_062_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3556/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P107
adata_107_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3594/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_107_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3539/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P089
adata_089_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3598/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_089_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3544/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P083
adata_083_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3602/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_083_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3547/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P074
adata_074_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3606/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_074_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3551/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
# Out:
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3496-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3563-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3502-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3569-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3592-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3537-filtered_feature_bc_matrix-matrix.h5ad
# ...

# %%
# Group B
#'P048','P039','P127','P054','P016','P002','P128','P031','P026','P012','P027','P079','P076','P052','P028',
#'P080','P062','P846','P181','P107','P089','P083','P074'
adata_048 = adata_048_1.concatenate(adata_048_2)
adata_039 = adata_039_1.concatenate(adata_039_2)
adata_127 = adata_127_1.concatenate(adata_127_2)
adata_054 = adata_054_1.concatenate(adata_054_2)
adata_016 = adata_016_1.concatenate(adata_016_2)
adata_002 = adata_002_1.concatenate(adata_002_2)
adata_128 = adata_127_1.concatenate(adata_127_2)
adata_031 = adata_031_1.concatenate(adata_031_2)
adata_026 = adata_026_1.concatenate(adata_026_2)
adata_012 = adata_012_1.concatenate(adata_012_2)
adata_027 = adata_027_1.concatenate(adata_027_2)
adata_079 = adata_079_1.concatenate(adata_079_2)
adata_076 = adata_076_1.concatenate(adata_076_2)
adata_052 = adata_052_1.concatenate(adata_052_2)
adata_028 = adata_028_1.concatenate(adata_028_2)
adata_080 = adata_080_1.concatenate(adata_080_2)
adata_062 = adata_062_1.concatenate(adata_062_2)
adata_846 = adata_846_1.concatenate(adata_846_2)
#addata_181
adata_107 = adata_107_1.concatenate(adata_107_2)
adata_089 = adata_089_1.concatenate(adata_089_2)
adata_083 = adata_083_1.concatenate(adata_083_2)
adata_074 = adata_074_1.concatenate(adata_074_2)

# %%
adata_31.obs
# Out:
#                                n_genes  n_genes_by_counts  total_counts  \
# AAACCTGAGATGTGTA-1-47-0-0-0-0   2776.0               2631   1555.039551
# AAACCTGAGCATCATC-1-47-0-0-0-0   2916.0               2825   1722.672241
# AAACCTGAGTACCGGA-1-47-0-0-0-0   1027.0                952   1001.220215
# AAACCTGGTCGCGAAA-1-47-0-0-0-0   3870.0               3655   1764.403320
# AAACGGGCAGCCTATA-1-47-0-0-0-0   1385.0               1363   1469.531616
# ...                                ...                ...           ...
# TTTGGTTTCGGTGTTA-1-3-1-1-0      1295.0               1266   1305.605347
# TTTGTCAAGGCTCAGA-1-3-1-1-0      1535.0               1493   1550.107056
# TTTGTCAGTCAGAGGT-1-3-1-1-0      1642.0               1615   1526.850708
# TTTGTCAGTTATCACG-1-3-1-1-0       937.0                892   1268.041626
# TTTGTCATCCTAGTGA-1-3-1-1-0      2002.0               1969   1696.932007
#
#                                total_counts_mt  pct_counts_mt tissue patient  \
# ...

# %%
adata_048.obs
# Out:
#                      batch
# AAACCTGAGATGTGTA-1-0     0
# AAACCTGAGCATCATC-1-0     0
# AAACCTGAGTACCGGA-1-0     0
# AAACCTGAGTATCTCG-1-0     0
# AAACCTGGTCGCGAAA-1-0     0
# ...                    ...
# TTTGTCAAGGCTCAGA-1-1     1
# TTTGTCAGTCAGAGGT-1-1     1
# TTTGTCAGTTATCACG-1-1     1
# TTTGTCATCCTAGTGA-1-1     1
# TTTGTCATCTAACTGG-1-1     1
#
# [5787 rows x 1 columns]

# %%
scv.utils.clean_obs_names(adata_31)
scv.utils.clean_obs_names(adata_32)
scv.utils.clean_obs_names(adata_33)
scv.utils.clean_obs_names(adata_34)
scv.utils.clean_obs_names(adata_35)
scv.utils.clean_obs_names(adata_36)
scv.utils.clean_obs_names(adata_37)
scv.utils.clean_obs_names(adata_38)
scv.utils.clean_obs_names(adata_39)
scv.utils.clean_obs_names(adata_40)
scv.utils.clean_obs_names(adata_41)
scv.utils.clean_obs_names(adata_42)
scv.utils.clean_obs_names(adata_43)
scv.utils.clean_obs_names(adata_44)
scv.utils.clean_obs_names(adata_45)
scv.utils.clean_obs_names(adata_46)
scv.utils.clean_obs_names(adata_47)
scv.utils.clean_obs_names(adata_48)
scv.utils.clean_obs_names(adata_49)
scv.utils.clean_obs_names(adata_50)
scv.utils.clean_obs_names(adata_51)
scv.utils.clean_obs_names(adata_52)
scv.utils.clean_obs_names(adata_53)

scv.utils.clean_obs_names(adata_048)
scv.utils.clean_obs_names(adata_039)
scv.utils.clean_obs_names(adata_127)
scv.utils.clean_obs_names(adata_054)
scv.utils.clean_obs_names(adata_016)
scv.utils.clean_obs_names(adata_002)
scv.utils.clean_obs_names(adata_128)
scv.utils.clean_obs_names(adata_031)
scv.utils.clean_obs_names(adata_026)
scv.utils.clean_obs_names(adata_012)
scv.utils.clean_obs_names(adata_027)
scv.utils.clean_obs_names(adata_079)
scv.utils.clean_obs_names(adata_076)
scv.utils.clean_obs_names(adata_052)
scv.utils.clean_obs_names(adata_028)
scv.utils.clean_obs_names(adata_080)
scv.utils.clean_obs_names(adata_062)
scv.utils.clean_obs_names(adata_846)
scv.utils.clean_obs_names(adata_836)
scv.utils.clean_obs_names(adata_107)
scv.utils.clean_obs_names(adata_089)
scv.utils.clean_obs_names(adata_083)
scv.utils.clean_obs_names(adata_074)

# %%
# Group B
#'P048','P039','P127','P054','P016','P002','P128','P031','P026','P012','P027','P079','P076','P052','P028',
#'P080','P062','P846','P181','P107','P089','P083','P074'
adata_31_3= scv.utils.merge(adata_31, adata_048)
adata_32_3= scv.utils.merge(adata_32, adata_039)
adata_33_3= scv.utils.merge(adata_33, adata_127)
adata_34_3= scv.utils.merge(adata_34, adata_054)
adata_35_3= scv.utils.merge(adata_35, adata_016)
adata_36_3= scv.utils.merge(adata_36, adata_002)
adata_37_3= scv.utils.merge(adata_37, adata_128)
adata_38_3= scv.utils.merge(adata_38, adata_031)
adata_39_3= scv.utils.merge(adata_39, adata_026)
adata_40_3= scv.utils.merge(adata_40, adata_012)
adata_41_3= scv.utils.merge(adata_41, adata_027)
adata_42_3= scv.utils.merge(adata_42, adata_079)
adata_43_3= scv.utils.merge(adata_43, adata_076)
adata_44_3= scv.utils.merge(adata_44, adata_052)
adata_45_3= scv.utils.merge(adata_45, adata_028)
adata_46_3= scv.utils.merge(adata_46, adata_080)
adata_47_3= scv.utils.merge(adata_47, adata_062)
adata_48_3= scv.utils.merge(adata_48, adata_846)
adata_49_3= scv.utils.merge(adata_49, adata_836)
adata_50_3= scv.utils.merge(adata_50, adata_107)
adata_51_3= scv.utils.merge(adata_51, adata_089)
adata_52_3= scv.utils.merge(adata_52, adata_083)
adata_53_3= scv.utils.merge(adata_53, adata_074)

# %%
# Group B
#'P048','P039','P127','P054','P016','P002','P128','P031','P026','P012','P027','P079','P076','P052','P028',
#'P080','P062','P846','P181','P107','P089','P083','P074'
adata_048.obs['celltype_detail'] = adata_31_3.obs['celltype_detail']
adata_048.obs['celltype'] = adata_31_3.obs['celltype']
adata_048.obs['crude'] = adata_31_3.obs['crude']
adata_048.obs['patient'] = adata_31_3.obs['patient']

adata_048_3 = adata_048[adata_048.obs['patient'].isin(['P048'])]

adata_039.obs['celltype_detail'] = adata_32_3.obs['celltype_detail']
adata_039.obs['celltype'] = adata_32_3.obs['celltype']
adata_039.obs['crude'] = adata_32_3.obs['crude']
adata_039.obs['patient'] = adata_32_3.obs['patient']

adata_039_3 = adata_039[adata_039.obs['patient'].isin(['P039'])]

adata_127.obs['celltype_detail'] = adata_33_3.obs['celltype_detail']
adata_127.obs['celltype'] = adata_33_3.obs['celltype']
adata_127.obs['crude'] = adata_33_3.obs['crude']
adata_127.obs['patient'] = adata_33_3.obs['patient']

adata_127_3 = adata_127[adata_127.obs['patient'].isin(['P127'])]

adata_054.obs['celltype_detail'] = adata_34_3.obs['celltype_detail']
adata_054.obs['celltype'] = adata_34_3.obs['celltype']
adata_054.obs['crude'] = adata_34_3.obs['crude']
adata_054.obs['patient'] = adata_34_3.obs['patient']

adata_054_3 = adata_054[adata_054.obs['patient'].isin(['P054'])]

adata_016.obs['celltype_detail'] = adata_35_3.obs['celltype_detail']
adata_016.obs['celltype'] = adata_35_3.obs['celltype']
adata_016.obs['crude'] = adata_35_3.obs['crude']
adata_016.obs['patient'] = adata_35_3.obs['patient']

adata_016_3 = adata_016[adata_016.obs['patient'].isin(['P016'])]

adata_002.obs['celltype_detail'] = adata_36_3.obs['celltype_detail']
adata_002.obs['celltype'] = adata_36_3.obs['celltype']
adata_002.obs['crude'] = adata_36_3.obs['crude']
adata_002.obs['patient'] = adata_36_3.obs['patient']

adata_002_3 = adata_002[adata_002.obs['patient'].isin(['P002'])]

adata_128.obs['celltype_detail'] = adata_37_3.obs['celltype_detail']
adata_128.obs['celltype'] = adata_37_3.obs['celltype']
adata_128.obs['crude'] = adata_37_3.obs['crude']
adata_128.obs['patient'] = adata_37_3.obs['patient']

adata_128_3 = adata_128[adata_128.obs['patient'].isin(['P128'])]

adata_031.obs['celltype_detail'] = adata_38_3.obs['celltype_detail']
adata_031.obs['celltype'] = adata_38_3.obs['celltype']
adata_031.obs['crude'] = adata_38_3.obs['crude']
adata_031.obs['patient'] = adata_38_3.obs['patient']

adata_031_3 = adata_031[adata_031.obs['patient'].isin(['P031'])]

adata_026.obs['celltype_detail'] = adata_39_3.obs['celltype_detail']
adata_026.obs['celltype'] = adata_39_3.obs['celltype']
adata_026.obs['crude'] = adata_39_3.obs['crude']
adata_026.obs['patient'] = adata_39_3.obs['patient']

adata_026_3 = adata_026[adata_026.obs['patient'].isin(['P026'])]

adata_012.obs['celltype_detail'] = adata_40_3.obs['celltype_detail']
adata_012.obs['celltype'] = adata_40_3.obs['celltype']
adata_012.obs['crude'] = adata_40_3.obs['crude']
adata_012.obs['patient'] = adata_40_3.obs['patient']

adata_012_3 = adata_012[adata_012.obs['patient'].isin(['P012'])]

adata_027.obs['celltype_detail'] = adata_41_3.obs['celltype_detail']
adata_027.obs['celltype'] = adata_41_3.obs['celltype']
adata_027.obs['crude'] = adata_41_3.obs['crude']
adata_027.obs['patient'] = adata_41_3.obs['patient']

adata_027_3 = adata_027[adata_027.obs['patient'].isin(['P027'])]

adata_079.obs['celltype_detail'] = adata_42_3.obs['celltype_detail']
adata_079.obs['celltype'] = adata_42_3.obs['celltype']
adata_079.obs['crude'] = adata_42_3.obs['crude']
adata_079.obs['patient'] = adata_42_3.obs['patient']

adata_079_3 = adata_079[adata_079.obs['patient'].isin(['P079'])]

adata_076.obs['celltype_detail'] = adata_43_3.obs['celltype_detail']
adata_076.obs['celltype'] = adata_43_3.obs['celltype']
adata_076.obs['crude'] = adata_43_3.obs['crude']
adata_076.obs['patient'] = adata_43_3.obs['patient']

adata_076_3 = adata_076[adata_076.obs['patient'].isin(['P076'])]

adata_052.obs['celltype_detail'] = adata_44_3.obs['celltype_detail']
adata_052.obs['celltype'] = adata_44_3.obs['celltype']
adata_052.obs['crude'] = adata_44_3.obs['crude']
adata_052.obs['patient'] = adata_44_3.obs['patient']

adata_052_3 = adata_052[adata_052.obs['patient'].isin(['P052'])]

adata_028.obs['celltype_detail'] = adata_45_3.obs['celltype_detail']
adata_028.obs['celltype'] = adata_45_3.obs['celltype']
adata_028.obs['crude'] = adata_45_3.obs['crude']
adata_028.obs['patient'] = adata_45_3.obs['patient']

adata_028_3 = adata_028[adata_028.obs['patient'].isin(['P028'])]

adata_080.obs['celltype_detail'] = adata_46_3.obs['celltype_detail']
adata_080.obs['celltype'] = adata_46_3.obs['celltype']
adata_080.obs['crude'] = adata_46_3.obs['crude']
adata_080.obs['patient'] = adata_46_3.obs['patient']

adata_080_3 = adata_080[adata_080.obs['patient'].isin(['P080'])]

adata_062.obs['celltype_detail'] = adata_47_3.obs['celltype_detail']
adata_062.obs['celltype'] = adata_47_3.obs['celltype']
adata_062.obs['crude'] = adata_47_3.obs['crude']
adata_062.obs['patient'] = adata_47_3.obs['patient']

adata_062_3 = adata_062[adata_062.obs['patient'].isin(['P062'])]

adata_846.obs['celltype_detail'] = adata_48_3.obs['celltype_detail']
adata_846.obs['celltype'] = adata_48_3.obs['celltype']
adata_846.obs['crude'] = adata_48_3.obs['crude']
adata_846.obs['patient'] = adata_48_3.obs['patient']

adata_846_3 = adata_846[adata_846.obs['patient'].isin(['P846'])]

adata_836.obs['celltype_detail'] = adata_49_3.obs['celltype_detail']
adata_836.obs['celltype'] = adata_49_3.obs['celltype']
adata_836.obs['crude'] = adata_49_3.obs['crude']
adata_836.obs['patient'] = adata_49_3.obs['patient']

adata_836_3 = adata_836[adata_836.obs['patient'].isin(['P836'])]

adata_107.obs['celltype_detail'] = adata_50_3.obs['celltype_detail']
adata_107.obs['celltype'] = adata_50_3.obs['celltype']
adata_107.obs['crude'] = adata_50_3.obs['crude']
adata_107.obs['patient'] = adata_50_3.obs['patient']

adata_107_3 = adata_107[adata_107.obs['patient'].isin(['P107'])]

adata_089.obs['celltype_detail'] = adata_51_3.obs['celltype_detail']
adata_089.obs['celltype'] = adata_51_3.obs['celltype']
adata_089.obs['crude'] = adata_51_3.obs['crude']
adata_089.obs['patient'] = adata_51_3.obs['patient']

adata_089_3 = adata_089[adata_089.obs['patient'].isin(['P089'])]

adata_083.obs['celltype_detail'] = adata_52_3.obs['celltype_detail']
adata_083.obs['celltype'] = adata_52_3.obs['celltype']
adata_083.obs['crude'] = adata_52_3.obs['crude']
adata_083.obs['patient'] = adata_52_3.obs['patient']

adata_083_3 = adata_083[adata_083.obs['patient'].isin(['P083'])]

adata_074.obs['celltype_detail'] = adata_53_3.obs['celltype_detail']
adata_074.obs['celltype'] = adata_53_3.obs['celltype']
adata_074.obs['crude'] = adata_53_3.obs['crude']
adata_074.obs['patient'] = adata_53_3.obs['patient']

adata_074_3 = adata_074[adata_074.obs['patient'].isin(['P074'])]

# %%
adata_048_3
# Out:
# View of AnnData object with n_obs × n_vars = 4240 × 36601
#     obs: 'batch', 'sample_batch', 'celltype_detail', 'celltype', 'crude', 'patient'
#     var: 'gene_ids', 'feature_types'

# %%
adata_048_3.write('P048_overlaid_for_cellchat.h5ad', compression='gzip')
adata_039_3.write('P039_overlaid_for_cellchat.h5ad', compression='gzip')
adata_127_3.write('P127_overlaid_for_cellchat.h5ad', compression='gzip')
adata_054_3.write('P054_overlaid_for_cellchat.h5ad', compression='gzip')
adata_016_3.write('P016_overlaid_for_cellchat.h5ad', compression='gzip')
adata_002_3.write('P002_overlaid_for_cellchat.h5ad', compression='gzip')
adata_128_3.write('P128_overlaid_for_cellchat.h5ad', compression='gzip')
adata_031_3.write('P031_overlaid_for_cellchat.h5ad', compression='gzip')
adata_026_3.write('P026_overlaid_for_cellchat.h5ad', compression='gzip')
adata_012_3.write('P012_overlaid_for_cellchat.h5ad', compression='gzip')
adata_027_3.write('P027_overlaid_for_cellchat.h5ad', compression='gzip')
adata_079_3.write('P079_overlaid_for_cellchat.h5ad', compression='gzip')
adata_076_3.write('P076_overlaid_for_cellchat.h5ad', compression='gzip')

adata_052_3.write('P052_overlaid_for_cellchat.h5ad', compression='gzip')
adata_028_3.write('P028_overlaid_for_cellchat.h5ad', compression='gzip')
adata_080_3.write('P080_overlaid_for_cellchat.h5ad', compression='gzip')


adata_062_3.write('P062_overlaid_for_cellchat.h5ad', compression='gzip')
adata_846_3.write('P846_overlaid_for_cellchat.h5ad', compression='gzip')
adata_836_3.write('P836_overlaid_for_cellchat.h5ad', compression='gzip')
adata_107_3.write('P107_overlaid_for_cellchat.h5ad', compression='gzip')
adata_089_3.write('P089_overlaid_for_cellchat.h5ad', compression='gzip')
adata_083_3.write('P083_overlaid_for_cellchat.h5ad', compression='gzip')
adata_074_3.write('P074_overlaid_for_cellchat.h5ad', compression='gzip')

# %%
# Group C
#'P130','010','P030','P015','P049','P037','P032','P075','P009B','P021','P019','P084','P011','P091','P065',
#'P057','P008','P042','P024','P020','P017','P023','P094','P061','P001'
adata_61 = sc.read('P130_for_cellchat.h5ad')
adata_62 = sc.read('P010_for_cellchat.h5ad')
adata_63 = sc.read('P030_for_cellchat.h5ad')
adata_64 = sc.read('P015_for_cellchat.h5ad')
adata_65 = sc.read('P049_for_cellchat.h5ad')
adata_66 = sc.read('P037_for_cellchat.h5ad')
adata_67 = sc.read('P032_for_cellchat.h5ad')
adata_68 = sc.read('P075_for_cellchat.h5ad')
adata_69 = sc.read('P009B_for_cellchat.h5ad')
adata_70 = sc.read('P021_for_cellchat.h5ad')
adata_71 = sc.read('P019_for_cellchat.h5ad')
adata_72 = sc.read('P084_for_cellchat.h5ad')
adata_73 = sc.read('P011_for_cellchat.h5ad')
adata_74 = sc.read('P091_for_cellchat.h5ad')
adata_75 = sc.read('P065_for_cellchat.h5ad')
adata_76 = sc.read('P057_for_cellchat.h5ad')
adata_77 = sc.read('P008_for_cellchat.h5ad')
adata_78 = sc.read('P042_for_cellchat.h5ad')
adata_79 = sc.read('P024_for_cellchat.h5ad')
adata_80 = sc.read('P020_for_cellchat.h5ad')
adata_81 = sc.read('P017_for_cellchat.h5ad')
adata_82 = sc.read('P023_for_cellchat.h5ad')
adata_83 = sc.read('P094_for_cellchat.h5ad')
adata_84 = sc.read('P061_for_cellchat.h5ad')
adata_85 = sc.read('P001_for_cellchat.h5ad')

# %%
adata_61
# Out:
# AnnData object with n_obs × n_vars = 3104 × 11060
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'tissue', 'patient', 'leiden', 'batch', 'total_counts_ribo', 'pct_counts_ribo', 'total_counts_hb', 'pct_counts_hb', 'percent_mt2', 'n_counts', 'source', 'patient_cluster', 'Notch_score', 'Tp53_score', 'Cdkn2a_score', 'NFkB_score', 'GOBP_tgfb_score', 'GOBP_notch_score', 'GOBP_wnt_score', 'GOBP_hippo_score', 'GOBP_cellcycle_score', 'GOBP_histone_score', 'GOBP_pi3k_score', 'celltype', 'crude', 'celltype_detail', 'dataset', 'T_patient_cluster4', 'Myeloid_patient_cluster4', 'Myeloid_to_T_cluster44', 'T_patient_cluster'
# ...

# %%
# Group C
#'P130','010','P030','P015','P049','P037','P032','P075','P009B','P021','P019','P084','P011','P091','P065',
#'P057','P008','P042','P024','P020','P017','P023','P094','P061','P001'

#P130
adata_130_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3589/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_130_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3535/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#010
adata_010_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3525/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_010_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3553/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P030
adata_030_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3508/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_030_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3576/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P015
adata_015_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3522/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_015_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3519/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P049
adata_049_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3495/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_049_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3562/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P037
adata_037_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3504/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_037_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3571/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P032
adata_032_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3506/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_032_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3573/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P075
adata_075_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3605/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_075_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3550/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P009B
adata_009B_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3529/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_009B_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3564/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P021
adata_021_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3516/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_021_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3587/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P019
adata_019_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3521/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_019_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3609/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P084
adata_084_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3601/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_084_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3546/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P011
adata_011_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3524/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_011_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3542/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P091
adata_091_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3596/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_091_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3564/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P065
adata_065_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3608/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_065_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3554/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P057
adata_057_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3490/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_057_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3557/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P008
adata_008_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3526/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_008_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3575/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#'P042','P024','P020','P017','P023','P094','P061','P001'

#P042
adata_042_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3499/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_042_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3566/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P024
adata_024_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3512/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_024_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3580/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P020
adata_020_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3517/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_020_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3597/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P017
adata_017_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3518/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_017_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3497/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P023
adata_023_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3514/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_023_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3581/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P094
adata_094_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3599/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_094_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3541/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P061
adata_061_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3489/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_061_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3560/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)

#P001
adata_001_1 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3528/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
adata_001_2 = sc.read_10x_mtx('E:/Ko/69_ESCC_files_from_F_Drive/56ESCC/ESCC_PRNA672851(Nature_Comm_60_patients)/3611/filtered_feature_bc_matrix', var_names='gene_symbols', cache=True)
# Out:
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3589-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3535-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3525-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3553-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3508-filtered_feature_bc_matrix-matrix.h5ad
# ... reading from cache file cache\E-Ko-69_ESCC_files_from_F_Drive-56ESCC-ESCC_PRNA672851(Nature_Comm_60_patients)-3576-filtered_feature_bc_matrix-matrix.h5ad
# ...

# %%
# Group C
#'P130','010','P030','P015','P049','P037','P032','P075','P009B','P021','P019','P084','P011','P091','P065',
#'P057','P008','P042','P024','P020','P017','P023','P094','P061','P001'
adata_130 = adata_130_1.concatenate(adata_130_2)
adata_010 = adata_010_1.concatenate(adata_010_2)
adata_030 = adata_030_1.concatenate(adata_030_2)
adata_015 = adata_015_1.concatenate(adata_015_2)
adata_049 = adata_049_1.concatenate(adata_049_2)
adata_037 = adata_037_1.concatenate(adata_037_2)
adata_032 = adata_032_1.concatenate(adata_032_2)
adata_075 = adata_075_1.concatenate(adata_075_2)
adata_009B = adata_009B_1.concatenate(adata_009B_2)
adata_021 = adata_021_1.concatenate(adata_021_2)
adata_019 = adata_019_1.concatenate(adata_019_2)
adata_084 = adata_084_1.concatenate(adata_084_2)
adata_011 = adata_011_1.concatenate(adata_011_2)
adata_091 = adata_091_1.concatenate(adata_091_2)
adata_065 = adata_065_1.concatenate(adata_065_2)
adata_057 = adata_057_1.concatenate(adata_057_2)
adata_008 = adata_008_1.concatenate(adata_008_2)
adata_042 = adata_042_1.concatenate(adata_042_2)

adata_024 = adata_024_1.concatenate(adata_024_2)
adata_020 = adata_020_1.concatenate(adata_020_2)
adata_017 = adata_017_1.concatenate(adata_017_2)
adata_023 = adata_023_1.concatenate(adata_023_2)
adata_094 = adata_094_1.concatenate(adata_094_2)
adata_061 = adata_061_1.concatenate(adata_061_2)
adata_001 = adata_001_1.concatenate(adata_001_2)

# %%
adata_61.obs
# Out:
#                                n_genes  n_genes_by_counts  total_counts  \
# AAACCTGGTGCGAAAC-1-22-0-1-0-1   1977.0               1909   2417.807373
# AAACGGGAGCGGCTTC-1-22-0-1-0-1   4916.0               4619   3584.264160
# AAACGGGGTTCACCTC-1-22-0-1-0-1   3328.0               3207   3037.968262
# AAAGATGAGATCGGGT-1-22-0-1-0-1   5428.0               5051   4022.194824
# AAAGATGCAAGACACG-1-22-0-1-0-1   4572.0               4398   3505.167725
# ...                                ...                ...           ...
# TTTGGTTGTTATGCGT-1-0-2-1-1      1623.0               1594   1921.322021
# TTTGGTTTCCACGAAT-1-0-2-1-1      1655.0               1627   1705.548828
# TTTGTCAAGCTCCTTC-1-0-2-1-1      4872.0               4740   2150.729980
# TTTGTCAAGGGATACC-1-0-2-1-1      1834.0               1800   1769.736084
# TTTGTCAGTTTCGCTC-1-0-2-1-1      1514.0               1487   1801.525146
#
#                                total_counts_mt  pct_counts_mt tissue patient  \
# ...

# %%
adata_130.obs
# Out:
#                      batch
# AAACCTGGTGCGAAAC-1-0     0
# AAACGGGAGCGGCTTC-1-0     0
# AAACGGGCATCCCATC-1-0     0
# AAACGGGGTGTGCGTC-1-0     0
# AAACGGGGTTCACCTC-1-0     0
# ...                    ...
# TTTGTCAAGCTCCTTC-1-1     1
# TTTGTCAAGGGATACC-1-1     1
# TTTGTCAAGTGTACTC-1-1     1
# TTTGTCAGTTTCGCTC-1-1     1
# TTTGTCATCGTCTGAA-1-1     1
#
# [4092 rows x 1 columns]

# %%
scv.utils.clean_obs_names(adata_61)
scv.utils.clean_obs_names(adata_62)
scv.utils.clean_obs_names(adata_63)
scv.utils.clean_obs_names(adata_64)
scv.utils.clean_obs_names(adata_65)
scv.utils.clean_obs_names(adata_66)
scv.utils.clean_obs_names(adata_67)
scv.utils.clean_obs_names(adata_68)
scv.utils.clean_obs_names(adata_69)
scv.utils.clean_obs_names(adata_70)
scv.utils.clean_obs_names(adata_71)
scv.utils.clean_obs_names(adata_72)
scv.utils.clean_obs_names(adata_73)
scv.utils.clean_obs_names(adata_74)
scv.utils.clean_obs_names(adata_75)
scv.utils.clean_obs_names(adata_76)
scv.utils.clean_obs_names(adata_77)
scv.utils.clean_obs_names(adata_78)
scv.utils.clean_obs_names(adata_79)
scv.utils.clean_obs_names(adata_80)
scv.utils.clean_obs_names(adata_81)
scv.utils.clean_obs_names(adata_82)
scv.utils.clean_obs_names(adata_83)
scv.utils.clean_obs_names(adata_84)
scv.utils.clean_obs_names(adata_85)

scv.utils.clean_obs_names(adata_130)
scv.utils.clean_obs_names(adata_010)
scv.utils.clean_obs_names(adata_030)
scv.utils.clean_obs_names(adata_015)
scv.utils.clean_obs_names(adata_049)
scv.utils.clean_obs_names(adata_037)
scv.utils.clean_obs_names(adata_032)
scv.utils.clean_obs_names(adata_075)
scv.utils.clean_obs_names(adata_009B)
scv.utils.clean_obs_names(adata_021)
scv.utils.clean_obs_names(adata_019)
scv.utils.clean_obs_names(adata_084)
scv.utils.clean_obs_names(adata_011)
scv.utils.clean_obs_names(adata_091)
scv.utils.clean_obs_names(adata_065)
scv.utils.clean_obs_names(adata_057)
scv.utils.clean_obs_names(adata_008)
scv.utils.clean_obs_names(adata_042)
scv.utils.clean_obs_names(adata_024)
scv.utils.clean_obs_names(adata_020)
scv.utils.clean_obs_names(adata_017)
scv.utils.clean_obs_names(adata_023)
scv.utils.clean_obs_names(adata_094)
scv.utils.clean_obs_names(adata_061)
scv.utils.clean_obs_names(adata_001)

# %%
# Group C
#'P130','010','P030','P015','P049','P037','P032','P075','P009B','P021','P019','P084','P011','P091','P065',
#'P057','P008','P042','P024','P020','P017','P023','P094','P061','P001'
adata_61_3= scv.utils.merge(adata_61, adata_130)
adata_62_3= scv.utils.merge(adata_62, adata_010)
adata_63_3= scv.utils.merge(adata_63, adata_030)
adata_64_3= scv.utils.merge(adata_64, adata_015)
adata_65_3= scv.utils.merge(adata_65, adata_049)
adata_66_3= scv.utils.merge(adata_66, adata_037)
adata_67_3= scv.utils.merge(adata_67, adata_032)
adata_68_3= scv.utils.merge(adata_68, adata_075)
adata_69_3= scv.utils.merge(adata_69, adata_009B)
adata_70_3= scv.utils.merge(adata_70, adata_021)
adata_71_3= scv.utils.merge(adata_71, adata_019)
adata_72_3= scv.utils.merge(adata_72, adata_084)
adata_73_3= scv.utils.merge(adata_73, adata_011)
adata_74_3= scv.utils.merge(adata_74, adata_091)
adata_75_3= scv.utils.merge(adata_75, adata_065)
adata_76_3= scv.utils.merge(adata_76, adata_057)
adata_77_3= scv.utils.merge(adata_77, adata_008)
adata_78_3= scv.utils.merge(adata_78, adata_042)
adata_79_3= scv.utils.merge(adata_79, adata_024)
adata_80_3= scv.utils.merge(adata_80, adata_020)
adata_81_3= scv.utils.merge(adata_81, adata_017)
adata_82_3= scv.utils.merge(adata_82, adata_023)
adata_83_3= scv.utils.merge(adata_83, adata_094)
adata_84_3= scv.utils.merge(adata_84, adata_061)
adata_85_3= scv.utils.merge(adata_85, adata_001)

# %%
# Group C
#'P130','010','P030','P015','P049','P037','P032','P075','P009B','P021','P019','P084','P011','P091','P065',
#'P057','P008','P042','P024','P020','P017','P023','P094','P061','P001'
adata_130.obs['celltype_detail'] = adata_61_3.obs['celltype_detail']
adata_130.obs['celltype'] = adata_61_3.obs['celltype']
adata_130.obs['crude'] = adata_61_3.obs['crude']
adata_130.obs['patient'] = adata_61_3.obs['patient']

adata_130_3 = adata_130[adata_130.obs['patient'].isin(['P130'])]

adata_010.obs['celltype_detail'] = adata_62_3.obs['celltype_detail']
adata_010.obs['celltype'] = adata_62_3.obs['celltype']
adata_010.obs['crude'] = adata_62_3.obs['crude']
adata_010.obs['patient'] = adata_62_3.obs['patient']

adata_010_3 = adata_010[adata_010.obs['patient'].isin(['P010'])]

adata_030.obs['celltype_detail'] = adata_63_3.obs['celltype_detail']
adata_030.obs['celltype'] = adata_63_3.obs['celltype']
adata_030.obs['crude'] = adata_63_3.obs['crude']
adata_030.obs['patient'] = adata_63_3.obs['patient']

adata_030_3 = adata_030[adata_030.obs['patient'].isin(['P030'])]

adata_015.obs['celltype_detail'] = adata_64_3.obs['celltype_detail']
adata_015.obs['celltype'] = adata_64_3.obs['celltype']
adata_015.obs['crude'] = adata_64_3.obs['crude']
adata_015.obs['patient'] = adata_64_3.obs['patient']

adata_015_3 = adata_015[adata_015.obs['patient'].isin(['P015'])]

adata_049.obs['celltype_detail'] = adata_65_3.obs['celltype_detail']
adata_049.obs['celltype'] = adata_65_3.obs['celltype']
adata_049.obs['crude'] = adata_65_3.obs['crude']
adata_049.obs['patient'] = adata_65_3.obs['patient']

adata_049_3 = adata_049[adata_049.obs['patient'].isin(['P049'])]

adata_037.obs['celltype_detail'] = adata_66_3.obs['celltype_detail']
adata_037.obs['celltype'] = adata_66_3.obs['celltype']
adata_037.obs['crude'] = adata_66_3.obs['crude']
adata_037.obs['patient'] = adata_66_3.obs['patient']

adata_037_3 = adata_037[adata_037.obs['patient'].isin(['P037'])]

adata_032.obs['celltype_detail'] = adata_67_3.obs['celltype_detail']
adata_032.obs['celltype'] = adata_67_3.obs['celltype']
adata_032.obs['crude'] = adata_67_3.obs['crude']
adata_032.obs['patient'] = adata_67_3.obs['patient']

adata_032_3 = adata_032[adata_032.obs['patient'].isin(['P032'])]

adata_075.obs['celltype_detail'] = adata_68_3.obs['celltype_detail']
adata_075.obs['celltype'] = adata_68_3.obs['celltype']
adata_075.obs['crude'] = adata_68_3.obs['crude']
adata_075.obs['patient'] = adata_68_3.obs['patient']

adata_075_3 = adata_075[adata_075.obs['patient'].isin(['P075'])]

adata_009B.obs['celltype_detail'] = adata_69_3.obs['celltype_detail']
adata_009B.obs['celltype'] = adata_69_3.obs['celltype']
adata_009B.obs['crude'] = adata_69_3.obs['crude']
adata_009B.obs['patient'] = adata_69_3.obs['patient']

adata_009B_3 = adata_009B[adata_009B.obs['patient'].isin(['P009B'])]

adata_021.obs['celltype_detail'] = adata_70_3.obs['celltype_detail']
adata_021.obs['celltype'] = adata_70_3.obs['celltype']
adata_021.obs['crude'] = adata_70_3.obs['crude']
adata_021.obs['patient'] = adata_70_3.obs['patient']

adata_021_3 = adata_021[adata_021.obs['patient'].isin(['P021'])]

adata_019.obs['celltype_detail'] = adata_71_3.obs['celltype_detail']
adata_019.obs['celltype'] = adata_71_3.obs['celltype']
adata_019.obs['crude'] = adata_71_3.obs['crude']
adata_019.obs['patient'] = adata_71_3.obs['patient']

adata_019_3 = adata_019[adata_019.obs['patient'].isin(['P019'])]

adata_084.obs['celltype_detail'] = adata_72_3.obs['celltype_detail']
adata_084.obs['celltype'] = adata_72_3.obs['celltype']
adata_084.obs['crude'] = adata_72_3.obs['crude']
adata_084.obs['patient'] = adata_72_3.obs['patient']

adata_084_3 = adata_084[adata_084.obs['patient'].isin(['P084'])]
#'P011','P091','P065',
#'P057','P008','P042','P024','P020','P017','P023','P094','P061','P001'
adata_011.obs['celltype_detail'] = adata_73_3.obs['celltype_detail']
adata_011.obs['celltype'] = adata_73_3.obs['celltype']
adata_011.obs['crude'] = adata_73_3.obs['crude']
adata_011.obs['patient'] = adata_73_3.obs['patient']

adata_011_3 = adata_011[adata_011.obs['patient'].isin(['P011'])]

adata_091.obs['celltype_detail'] = adata_74_3.obs['celltype_detail']
adata_091.obs['celltype'] = adata_74_3.obs['celltype']
adata_091.obs['crude'] = adata_74_3.obs['crude']
adata_091.obs['patient'] = adata_74_3.obs['patient']

adata_091_3 = adata_091[adata_091.obs['patient'].isin(['P091'])]

adata_065.obs['celltype_detail'] = adata_75_3.obs['celltype_detail']
adata_065.obs['celltype'] = adata_75_3.obs['celltype']
adata_065.obs['crude'] = adata_75_3.obs['crude']
adata_065.obs['patient'] = adata_75_3.obs['patient']

adata_065_3 = adata_065[adata_065.obs['patient'].isin(['P065'])]

adata_057.obs['celltype_detail'] = adata_76_3.obs['celltype_detail']
adata_057.obs['celltype'] = adata_76_3.obs['celltype']
adata_057.obs['crude'] = adata_76_3.obs['crude']
adata_057.obs['patient'] = adata_76_3.obs['patient']

adata_057_3 = adata_057[adata_057.obs['patient'].isin(['P057'])]

adata_008.obs['celltype_detail'] = adata_77_3.obs['celltype_detail']
adata_008.obs['celltype'] = adata_77_3.obs['celltype']
adata_008.obs['crude'] = adata_77_3.obs['crude']
adata_008.obs['patient'] = adata_77_3.obs['patient']

adata_008_3 = adata_008[adata_008.obs['patient'].isin(['P008'])]

adata_042.obs['celltype_detail'] = adata_78_3.obs['celltype_detail']
adata_042.obs['celltype'] = adata_78_3.obs['celltype']
adata_042.obs['crude'] = adata_78_3.obs['crude']
adata_042.obs['patient'] = adata_78_3.obs['patient']

adata_042_3 = adata_042[adata_042.obs['patient'].isin(['P042'])]

adata_024.obs['celltype_detail'] = adata_79_3.obs['celltype_detail']
adata_024.obs['celltype'] = adata_79_3.obs['celltype']
adata_024.obs['crude'] = adata_79_3.obs['crude']
adata_024.obs['patient'] = adata_79_3.obs['patient']

adata_024_3 = adata_024[adata_024.obs['patient'].isin(['P024'])]

adata_020.obs['celltype_detail'] = adata_80_3.obs['celltype_detail']
adata_020.obs['celltype'] = adata_80_3.obs['celltype']
adata_020.obs['crude'] = adata_80_3.obs['crude']
adata_020.obs['patient'] = adata_80_3.obs['patient']

adata_020_3 = adata_020[adata_020.obs['patient'].isin(['P020'])]

adata_017.obs['celltype_detail'] = adata_81_3.obs['celltype_detail']
adata_017.obs['celltype'] = adata_81_3.obs['celltype']
adata_017.obs['crude'] = adata_81_3.obs['crude']
adata_017.obs['patient'] = adata_81_3.obs['patient']
adata_017_3 = adata_017[adata_017.obs['patient'].isin(['P017'])]

adata_023.obs['celltype_detail'] = adata_82_3.obs['celltype_detail']
adata_023.obs['celltype'] = adata_82_3.obs['celltype']
adata_023.obs['crude'] = adata_82_3.obs['crude']
adata_023.obs['patient'] = adata_82_3.obs['patient']

adata_023_3 = adata_023[adata_023.obs['patient'].isin(['P023'])]

adata_094.obs['celltype_detail'] = adata_83_3.obs['celltype_detail']
adata_094.obs['celltype'] = adata_83_3.obs['celltype']
adata_094.obs['crude'] = adata_83_3.obs['crude']
adata_094.obs['patient'] = adata_83_3.obs['patient']

adata_094_3 = adata_094[adata_094.obs['patient'].isin(['P094'])]

adata_061.obs['celltype_detail'] = adata_84_3.obs['celltype_detail']
adata_061.obs['celltype'] = adata_84_3.obs['celltype']
adata_061.obs['crude'] = adata_84_3.obs['crude']
adata_061.obs['patient'] = adata_84_3.obs['patient']

adata_061_3 = adata_061[adata_061.obs['patient'].isin(['P061'])]

adata_001.obs['celltype_detail'] = adata_85_3.obs['celltype_detail']
adata_001.obs['celltype'] = adata_85_3.obs['celltype']
adata_001.obs['crude'] = adata_85_3.obs['crude']
adata_001.obs['patient'] = adata_85_3.obs['patient']

adata_001_3 = adata_001[adata_001.obs['patient'].isin(['P001'])]

# %%
adata_130_3
# Out:
# View of AnnData object with n_obs × n_vars = 3104 × 36601
#     obs: 'batch', 'sample_batch', 'celltype_detail', 'celltype', 'crude', 'patient'
#     var: 'gene_ids', 'feature_types'

# %%
# Group C
#'P130','010','P030','P015','P049','P037','P032','P075','P009B','P021','P019','P084','P011','P091','P065',
#'P057','P008','P042','P024','P020','P017','P023','P094','P061','P001'
adata_130_3.write('P130_overlaid_for_cellchat.h5ad', compression='gzip')
adata_010_3.write('P010_overlaid_for_cellchat.h5ad', compression='gzip')
adata_030_3.write('P030_overlaid_for_cellchat.h5ad', compression='gzip')
adata_015_3.write('P015_overlaid_for_cellchat.h5ad', compression='gzip')
adata_049_3.write('P049_overlaid_for_cellchat.h5ad', compression='gzip')
adata_037_3.write('P037_overlaid_for_cellchat.h5ad', compression='gzip')
adata_032_3.write('P032_overlaid_for_cellchat.h5ad', compression='gzip')
adata_075_3.write('P075_overlaid_for_cellchat.h5ad', compression='gzip')
adata_009B_3.write('P009B_overlaid_for_cellchat.h5ad', compression='gzip')
adata_021_3.write('P021_overlaid_for_cellchat.h5ad', compression='gzip')
adata_019_3.write('P019_overlaid_for_cellchat.h5ad', compression='gzip')
adata_084_3.write('P084_overlaid_for_cellchat.h5ad', compression='gzip')
adata_011_3.write('P011_overlaid_for_cellchat.h5ad', compression='gzip')

adata_091_3.write('P091_overlaid_for_cellchat.h5ad', compression='gzip')
adata_065_3.write('P065_overlaid_for_cellchat.h5ad', compression='gzip')
adata_057_3.write('P057_overlaid_for_cellchat.h5ad', compression='gzip')


adata_008_3.write('P008_overlaid_for_cellchat.h5ad', compression='gzip')
adata_042_3.write('P042_overlaid_for_cellchat.h5ad', compression='gzip')
adata_024_3.write('P024_overlaid_for_cellchat.h5ad', compression='gzip')
adata_020_3.write('P020_overlaid_for_cellchat.h5ad', compression='gzip')
adata_017_3.write('P017_overlaid_for_cellchat.h5ad', compression='gzip')
adata_023_3.write('P023_overlaid_for_cellchat.h5ad', compression='gzip')
adata_094_3.write('P094_overlaid_for_cellchat.h5ad', compression='gzip')
adata_061_3.write('P061_overlaid_for_cellchat.h5ad', compression='gzip')
adata_001_3.write('P001_overlaid_for_cellchat.h5ad', compression='gzip')

# %%
adata_009_3= sc.read('P009A_overlaid_for_cellchat.h5ad')

# %%
adata_036_3= sc.read('P036_overlaid_for_cellchat.h5ad')
adata_126_3= sc.read('P126_overlaid_for_cellchat.h5ad')
adata_038_3= sc.read('P038_overlaid_for_cellchat.h5ad')
adata_104_3= sc.read('P104_overlaid_for_cellchat.h5ad')
adata_082_3= sc.read('P082_overlaid_for_cellchat.h5ad')
adata_063_3= sc.read('P063_overlaid_for_cellchat.h5ad')
adata_056_3= sc.read('P056_overlaid_for_cellchat.h5ad')
adata_866_3= sc.read('P866_overlaid_for_cellchat.h5ad')
adata_686_3= sc.read('P686_overlaid_for_cellchat.h5ad')
adata_658_3= sc.read('P658_overlaid_for_cellchat.h5ad')
adata_787_3= sc.read('P787_overlaid_for_cellchat.h5ad')
adata_986_3= sc.read('P986_overlaid_for_cellchat.h5ad')
adata_585_3= sc.read('P585_overlaid_for_cellchat.h5ad')
adata_944_3= sc.read('P944_overlaid_for_cellchat.h5ad')
adata_865_3= sc.read('P865_overlaid_for_cellchat.h5ad')
adata_087_3= sc.read('P087_overlaid_for_cellchat.h5ad')
adata_047_3= sc.read('P047_overlaid_for_cellchat.h5ad')
adata_040_3= sc.read('P040_overlaid_for_cellchat.h5ad')
adata_044_3= sc.read('P044_overlaid_for_cellchat.h5ad')
adata_022_3= sc.read('P022_overlaid_for_cellchat.h5ad')



adata_048_3= sc.read('P048_overlaid_for_cellchat.h5ad')
adata_039_3= sc.read('P039_overlaid_for_cellchat.h5ad')
adata_127_3= sc.read('P127_overlaid_for_cellchat.h5ad')
adata_054_3= sc.read('P054_overlaid_for_cellchat.h5ad')
adata_016_3= sc.read('P016_overlaid_for_cellchat.h5ad')
adata_002_3= sc.read('P002_overlaid_for_cellchat.h5ad')
adata_128_3= sc.read('P128_overlaid_for_cellchat.h5ad')
adata_031_3= sc.read('P031_overlaid_for_cellchat.h5ad')
adata_026_3= sc.read('P026_overlaid_for_cellchat.h5ad')
adata_012_3= sc.read('P012_overlaid_for_cellchat.h5ad')
adata_027_3= sc.read('P027_overlaid_for_cellchat.h5ad')
adata_079_3= sc.read('P079_overlaid_for_cellchat.h5ad')
adata_076_3= sc.read('P076_overlaid_for_cellchat.h5ad')
adata_052_3= sc.read('P052_overlaid_for_cellchat.h5ad')
adata_028_3= sc.read('P028_overlaid_for_cellchat.h5ad')
adata_080_3= sc.read('P080_overlaid_for_cellchat.h5ad')
adata_062_3= sc.read('P062_overlaid_for_cellchat.h5ad')
adata_846_3= sc.read('P846_overlaid_for_cellchat.h5ad')
adata_836_3= sc.read('P836_overlaid_for_cellchat.h5ad')
adata_107_3= sc.read('P107_overlaid_for_cellchat.h5ad')
adata_089_3= sc.read('P089_overlaid_for_cellchat.h5ad')
adata_083_3= sc.read('P083_overlaid_for_cellchat.h5ad')
adata_074_3= sc.read('P074_overlaid_for_cellchat.h5ad')


adata_130_3= sc.read('P130_overlaid_for_cellchat.h5ad')
adata_010_3= sc.read('P010_overlaid_for_cellchat.h5ad')
adata_030_3= sc.read('P030_overlaid_for_cellchat.h5ad')
adata_015_3= sc.read('P015_overlaid_for_cellchat.h5ad')
adata_049_3= sc.read('P049_overlaid_for_cellchat.h5ad')
adata_037_3= sc.read('P037_overlaid_for_cellchat.h5ad')
adata_032_3= sc.read('P032_overlaid_for_cellchat.h5ad')
adata_075_3= sc.read('P075_overlaid_for_cellchat.h5ad')
adata_009B_3= sc.read('P009B_overlaid_for_cellchat.h5ad')
adata_021_3= sc.read('P021_overlaid_for_cellchat.h5ad')
adata_019_3= sc.read('P019_overlaid_for_cellchat.h5ad')
adata_084_3= sc.read('P084_overlaid_for_cellchat.h5ad')
adata_011_3= sc.read('P011_overlaid_for_cellchat.h5ad')
adata_091_3= sc.read('P091_overlaid_for_cellchat.h5ad')
adata_065_3= sc.read('P065_overlaid_for_cellchat.h5ad')
adata_057_3= sc.read('P057_overlaid_for_cellchat.h5ad')
adata_008_3= sc.read('P008_overlaid_for_cellchat.h5ad')
adata_042_3= sc.read('P042_overlaid_for_cellchat.h5ad')
adata_024_3= sc.read('P024_overlaid_for_cellchat.h5ad')
adata_020_3= sc.read('P020_overlaid_for_cellchat.h5ad')
adata_017_3= sc.read('P017_overlaid_for_cellchat.h5ad')
adata_023_3= sc.read('P023_overlaid_for_cellchat.h5ad')
adata_094_3= sc.read('P094_overlaid_for_cellchat.h5ad')
adata_061_3= sc.read('P061_overlaid_for_cellchat.h5ad')
adata_001_3= sc.read('P001_overlaid_for_cellchat.h5ad')

# %%
adata_total = adata_009_3.concatenate(adata_036_3,adata_126_3,adata_038_3,adata_104_3,adata_082_3,adata_063_3,adata_056_3,
                                      adata_866_3,adata_686_3,adata_658_3,adata_787_3,adata_986_3,adata_585_3,adata_944_3,
                                      adata_865_3,adata_087_3,adata_047_3,adata_040_3,adata_044_3,adata_022_3,
                                     
                                      adata_048_3, adata_039_3,adata_127_3,adata_054_3,adata_016_3,adata_002_3,adata_128_3,adata_031_3,
                                      adata_026_3,adata_012_3,adata_027_3,adata_079_3,adata_076_3,adata_052_3,adata_028_3,
                                      adata_080_3,adata_062_3,adata_846_3,adata_836_3,adata_107_3,adata_089_3,
                                      adata_083_3,adata_074_3,
                                      
                                      adata_130_3,adata_010_3,adata_030_3,adata_015_3,adata_049_3,adata_037_3,adata_032_3,adata_075_3,
                                      adata_009B_3,adata_021_3,adata_019_3,adata_084_3,adata_011_3,adata_091_3,adata_065_3,
                                      adata_057_3,adata_008_3,adata_042_3,adata_024_3,adata_020_3,adata_017_3,
                                      adata_023_3,adata_094_3,adata_061_3,adata_001_3)

# %%
# Fill in the clusters that belong to each cell type based on each marker in the plot above
cell_dict = {'T_1': ['P010','P008','P021','P049','P020','P062','P032','P016','P061','P012',
                     'P057','P015','P065','P063','P130','P056', 'P011','P127','P126','P001',
                     'P028','P027','P030'],
             'T_2': ['P037','P031','P026','P042','P019','P017','P036','P054','P023','P128',
                     'P048','P002','P104','P087','P094','P084','P079','P107','P076','P089',
                     'P083'],
                     
                   
             'T_3': [ 'P986','P658','P836','P866','P846','P686','P865','P585','P944','P787'],
             'T_4': ['P052','P024','P040','P039','P080','P075','P091','P009B','P082','P022',
                     'P074','P047','P038','P044','P009A']
              }

# Initialize empty column in cell metadata
adata_total.obs['T_patient_cluster'] = np.nan

# Generate new assignments
for i in cell_dict.keys():
    ind = pd.Series(adata_total.obs.patient).isin(cell_dict[i])
    adata_total.obs.loc[ind,'T_patient_cluster4'] = i

# %%
# Fill in the clusters that belong to each cell type based on each marker in the plot above
cell_dict = {'Myeloid_1': ['P063','P056','P009B','P075','P011','P032','P016','P104','P087','P089','P036','P083','P052',
                          'P047','P037','P091','P022','P074','P038','P082'],
            'Myeloid_2':  ['P130','P010','P986','P865','P585','P866','P846','P686','P658','P944','P836','P787'],
             'Myeloid_3': ['P040','P024','P017','P031','P026','P023','P049','P021','P107','P076','P079','P048','P062',
                          'P027','P065','P057','P008','P044','P001','P042','P094','P084','P080','P002','P061','P015'],
             'Myeloid_4': ['P128','P054','P019','P127','P126','P030','P028','P039','P020','P012']
              
              }

# Initialize empty column in cell metadata
adata_total.obs['Myeloid_patient_cluster4'] = np.nan

# Generate new assignments
for i in cell_dict.keys():
    ind = pd.Series(adata_total.obs.patient).isin(cell_dict[i])
    adata_total.obs.loc[ind,'Myeloid_patient_cluster4'] = i

# %%
# Fill in the clusters that belong to each cell type based on each marker in the plot above
cell_dict = {'M1toT1': ["P011",	"P016",	"P032",	"P056",	"P063",
],
             'M1toT2': ["P036",	"P037",	"P083",	"P087",	"P089",	"P104",
],
             'M1toT3': [],
             'M1toT4': ["P009B",	"P022",	"P038",	"P047",	"P052",	"P074",	"P075",	"P082",	"P091",
],
             'M2toT1': ["P010",	"P130",
],
             'M2toT2': [],
             'M2toT3': ["P585",	"P658",	"P686",	"P787",	"P836",	"P846",	"P865",	"P866",	"P944",	"P986",
],
             'M2toT4': [],
             'M3toT1': ["P001",	"P008",	"P015",	"P021",	"P027",	"P049",	"P057",	"P061",	"P062",	"P065",
],
             'M3toT2': ["P002",	"P017",	"P023",	"P026",	"P031",	"P042",	"P048",	"P076",	"P079",	"P084",	"P094",	"P107",
],
             'M3toT3': [],
             'M3toT4': ["P024",	"P040",	"P044",	"P080",
],
             'M4toT1': ["P012",	"P020",	"P028",	"P030",	"P126",	"P127",
],
             'M4toT2': ["P019",	"P054",	"P128",
],
             'M4toT3': [],
             'M4toT4': ["P039",
],
             'NoMtoT4': ["P009A",
]
            }

# Initialize empty column in cell metadata
adata_total.obs['Myeloid_to_T_cluster44'] = np.nan

# Generate new assignments
for i in cell_dict.keys():
    ind = pd.Series(adata_total.obs.patient).isin(cell_dict[i])
    adata_total.obs.loc[ind,'Myeloid_to_T_cluster44'] = i

# %%
# subgrouping by Myeloid group
adata_M1toT1 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M1toT1']
adata_M1toT2 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M1toT2']
adata_M1toT4 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M1toT4']
adata_M2toT1 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M2toT1']
#adata_M2toT2 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M2toT2']
adata_M2toT3 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M2toT3']
adata_M3toT1 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M3toT1']
adata_M3toT2 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M3toT2']
adata_M3toT4 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M3toT4']
adata_M4toT1 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M4toT1']
adata_M4toT2 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M4toT2']
adata_M4toT4 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='M4toT4']

adata_NoMT4 = adata_total[adata_total.obs['Myeloid_to_T_cluster44']=='NoMtoT4']

# %%
adata_NoMT4
# Out:
# View of AnnData object with n_obs × n_vars = 16391 × 36601
#     obs: 'sample_batch', 'celltype_detail', 'celltype', 'crude', 'patient', 'batch', 'T_patient_cluster', 'T_patient_cluster4', 'Myeloid_patient_cluster4', 'Myeloid_to_T_cluster44'
#     var: 'gene_ids', 'feature_types'

# %%
del adata_NoMT4.obs['Myeloid_patient_cluster4']

# %%
adata_M1toT1.write('M1toT1_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M1toT2.write('M1toT2_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M1toT4.write('M1toT4_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M2toT1.write('M2toT1_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M2toT3.write('M2toT3_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M3toT1.write('M3toT1_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M3toT2.write('M3toT2_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M3toT4.write('M3toT4_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M4toT1.write('M4toT1_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M4toT2.write('M4toT2_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_M4toT4.write('M4toT4_overlaid_for_cellchat.h5ad', compression= 'gzip')
adata_NoMT4.write('NoMtoT4_overlaid_for_cellchat.h5ad', compression= 'gzip')

# %%
adata_NoMtoT4 = sc.read('NoMtoT4_overlaid_for_cellchat.h5ad')

# %%
adata_M1toT4.obs['celltype_detail']
# Out:
# AAACCTGCAATA-3                Tumor
# AAACCTGGTGTC-3                Tumor
# AAACCTGTCGCC-3           Fibroblast
# AAACGGGAGCTT-3                Tumor
# AAAGATGGTCTA-3                Tumor
#                          ...
# TTCTACACAGCC-57          CD4 T cell
# TTGCCGTTCTAA-57    exhausted T cell
# TTGGCAATCGCC-57            Monocyte
# TTTACTGGTAAC-57     effector T cell
# TTTGTCATCTTG-57            Monocyte
# Name: celltype_detail, Length: 36667, dtype: category
# Categories (14, object): ['B cell', 'CD4 T cell', 'CD8 T cell', 'Fibroblast', ..., 'T cell', 'Tumor', 'effector T cell', 'exhausted T cell']
